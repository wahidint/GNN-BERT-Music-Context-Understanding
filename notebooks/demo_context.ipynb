# %% [markdown]
# # Music Context Understanding Demo
#
# End-to-end inference demonstration.

# %%
caption = 'A calm piano melody with soft instrumental background'
print('Input caption:', caption)

# %%
print('Pipeline: Caption -> BERT Encoder -> GNN Representation -> Fusion -> Prediction')

# %% [markdown]
# The notebook demonstrates the intended inference flow using the trained components.
